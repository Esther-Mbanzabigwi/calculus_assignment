# %% [markdown]
# # Task 1: Write a dynamic function to find the derivative of any function f(x)

# %%
import sympy as sp

def dy_dx(f):
    # Define the symbol
    x = sp.symbols('x')

    # Calculate the derivative
    derivative = sp.diff(f, x)

    return derivative

# Example usage
# Define the function f(x)
x = sp.symbols('x')
f = x**2 + 3*x + 2

# Calculate the derivative
derivative = dy_dx(f)
print(derivative)
# Out:
# 2*x + 3

# %% [markdown]
# # Task 2: Test the derivative function written with an equation of your choice
# *NB: Must have atleast 2 minimas and atleast 2 maximas*

# %%
import numpy as np

# Define the function
def f(x):
    return x**5 - 10*x**3 + 20*x

# Generate x values
x = np.linspace(-4, 4, 400)

# Generate y values
y = f(x)

print (y)
# Out:
# [-4.64000000e+02 -4.47766735e+02 -4.31944349e+02 -4.16525704e+02
#  -4.01503737e+02 -3.86871463e+02 -3.72621974e+02 -3.58748436e+02
#  -3.45244090e+02 -3.32102253e+02 -3.19316317e+02 -3.06879745e+02
#  -2.94786077e+02 -2.83028925e+02 -2.71601974e+02 -2.60498981e+02
#  -2.49713776e+02 -2.39240261e+02 -2.29072407e+02 -2.19204260e+02
#  -2.09629932e+02 -2.00343608e+02 -1.91339543e+02 -1.82612060e+02
#  -1.74155552e+02 -1.65964481e+02 -1.58033374e+02 -1.50356831e+02
#  -1.42929516e+02 -1.35746160e+02 -1.28801562e+02 -1.22090588e+02
#  -1.15608168e+02 -1.09349298e+02 -1.03309040e+02 -9.74825194e+01
#  -9.18649276e+01 -8.64515188e+01 -8.12376109e+01 -7.62185854e+01
#  -7.13898862e+01 -6.67470199e+01 -6.22855548e+01 -5.80011212e+01
#  -5.38894104e+01 -4.99461745e+01 -4.61672263e+01 -4.25484386e+01
#  -3.90857436e+01 -3.57751333e+01 -3.26126582e+01 -2.95944275e+01
#  -2.67166085e+01 -2.39754262e+01 -2.13671629e+01 -1.88881582e+01
# ...

# %% [markdown]
# #Task 3: Plot a graph of the Equation must have 4 points (2 minimas and 2 maximas)

# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt
#
# def f(x):
#     return 2*x**4 - 8*x**3 - 6*x**2 + 4*x + 5
#
# # Generate x values
# x = np.linspace(-2, 3, 400)
# # Calculate corresponding y values
# y = f(x)
#
# # Find minima and maxima
# from scipy.signal import argrelextrema
#
# # Find local minima
# minima_indices = argrelextrema(y, np.less)[0]
# maxima_indices = argrelextrema(y, np.greater)[0]
#
# minima_x = x[minima_indices]
# minima_y = y[minima_indices]
#
# maxima_x = x[maxima_indices]
# maxima_y = y[maxima_indices]
#
# # Plot the function
# plt.figure(figsize=(10, 6))
# plt.plot(x, y, label='f(x) = 2x^4 - 8x^3 - 6x^2 + 4x + 5', color='b')
# plt.scatter(minima_x, minima_y, color='red', label='Minima')
# plt.scatter(maxima_x, maxima_y, color='green', label='Maxima')
#
# plt.title('Graph of f(x)')
# plt.xlabel('x')
# plt.ylabel('f(x)')
# plt.grid(True)
# plt.axhline(0, color='black', linewidth=0.5)  # horizontal line at y=0
#
# # Adding annotations for minima
# for i in range(len(minima_x)):
#     plt.text(minima_x[i], minima_y[i], f'({minima_x[i]:.2f}, {minima_y[i]:.2f})', fontsize=10, verticalalignment='bottom')
#
# # Adding annotations for maxima
# for i in range(len(maxima_x)):
#     plt.text(maxima_x[i], maxima_y[i], f'({maxima_x[i]:.2f}, {maxima_y[i]:.2f})', fontsize=10, verticalalignment='top')
#
# plt.legend()
# plt.show()

# %% [markdown]
# # Task 4: Create separate array of Minimas and maximas

# %%
import numpy as np
from scipy.optimize import fsolve

# Define the modified function
def f(x):
    return x**5 - 5*x**3 + 10*x

# Define the derivative of the function
def df(x):
    return 5*x**4 - 15*x**2 + 10

# Generate x values
x = np.linspace(-3, 3, 400)

# Generate y values for the function and its derivative
y = f(x)
dy = df(x)

# Initial guesses for the roots (critical points)
initial_guesses = [-2, -1, 0, 1, 2]
critical_points = fsolve(df, initial_guesses)

# Calculate function values at critical points
critical_values = f(critical_points)

# Filter out the critical points that are minima and maxima
minima = [cp for cp, val in zip(critical_points, critical_values) if df(cp + 1e-5) > 0]
maxima = [cp for cp, val in zip(critical_points, critical_values) if df(cp + 1e-5) < 0]

# Create arrays to store minima and maxima
arr_minimas = list(zip(minima, f(np.array(minima))))
arr_maximas = list(zip(maxima, f(np.array(maxima))))

# Print the arrays of minima and maxima
print(f'The array of minimas is {arr_minimas} and the array of maximas is {arr_maximas}')
# Out:
# The array of minimas is [(-2.0, -12.0), (-1.0, -6.0), (0.0, 0.0), (2.0, 12.0)] and the array of maximas is [(1.0, 6.0)]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def f(x):
    return x**5 - 10*x**3 + 20*x

# Generate x values
x = np.linspace(-4, 4, 400)

# Generate y values
y = f(x)

# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='f(x) = x^5 - 10x^3 + 20x')
plt.title('Plot of the function with 2 minima and 2 maxima')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()
plt.show()

# %% [markdown]
# #Finally, What is the global Minima and the Global maxima _ Plot this so that I can see

# %%
#This is an Example of a quadratic function
def f(x):
   return (4 * (x** 2)) + (x ** -1)

# %% [markdown]
# We manuall calculated the derivative  and got that
# $$
# df(x)/dx = 8x^1 + x^-2
# $$
#
# Using the formula above we find points where the derivative is 0
#
# the values are:
#
# $$
# x1 = 0.5, x1 = - 0.5,x1 = 0,
# $$
#
# If you replace this in our original formula
#
# $$
# f(0.5) = 4(0.5)^2 + (0.5^-1 = -1.0
# $$
# $$
# f(0) = 4x^2 + x^-1 = No solution
# $$
# $$
# f(-0.5) = 4x^2 + x^-1 = 1
# $$
#
# Meaning our curve is flat at point $$(0.5,1) $$ and at $$ (-0.5,1)$$
#
# Proof Pending........
#
# Here is how we tried with code and got some errors

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function g(x)
def g(x):
    return x**3 - 3*x

# Generate x values
x = np.linspace(-2, 2, 400)
y = g(x)

# Find global minimum and maximum
global_min_x = 1
global_max_x = -1
global_min_y = g(global_min_x)
global_max_y = g(global_max_x)

# Plot the function g(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='g(x) = x^3 - 3x', color='b')

# Marking global minimum and maximum
plt.scatter(global_min_x, global_min_y, color='red', label='Global Minimum')
plt.scatter(global_max_x, global_max_y, color='green', label='Global Maximum')

# Annotate global minimum and maximum
plt.text(global_min_x, global_min_y, f'Global Minimum: ({global_min_x}, {global_min_y:.2f})',
         fontsize=10, verticalalignment='top', horizontalalignment='right')
plt.text(global_max_x, global_max_y, f'Global Maximum: ({global_max_x}, {global_max_y:.2f})',
         fontsize=10, verticalalignment='bottom', horizontalalignment='right')

plt.title('Graph of g(x)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.grid(True)

plt.legend()
plt.show()

# %% [markdown]
# # **You can now do the Rest.All the Best ........**
